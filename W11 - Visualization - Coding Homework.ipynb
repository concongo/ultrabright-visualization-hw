# %% [markdown]
# ## W11 - Visualization - Coding Homework

# %% [markdown]
# For this Coding Homework, you are required to complete a EDA (Exploratory Data Analysis) of Toy Dataset constructed just for this purpose. The dataset is based on a Kaggle data set of the Rolling Stone's 500 greatest albums (https://www.kaggle.com/notgibs/500-greatest-albums-of-all-time-rolling-stone), but it's not identical. Please follow the notebook and fill all sections asked.

# %% [markdown]
# **0. Import all the needed libraries**

# %%
# Libraries

# %% [markdown]
# **1. Load the Dataset which is stored in the file named `albumlist.csv` remember to import all the libraries needed**

# %%
#### YOUR CODE HERE

# %% [markdown]
# **2. Print the first 10 rows and the last 10 rows of the dataset. Then describe it.**

# %%
#### YOUR CODE HERE - FIRST TEN ROWS

# %%
#### YOUR CODE HERE - LAST TEN ROWS

# %%
### DESCRIBE DATASET

# %% [markdown]
# **3. Create a Distribution Plot of the Album `Year` for just for those Albums in the Rock Genre**

# %%
#### YOUR CODE HERE
# Out:
# (array([ 1., 13., 80., 56., 36., 20., 22.,  4., 13.,  4.]),
#  array([1956. , 1961.5, 1967. , 1972.5, 1978. , 1983.5, 1989. , 1994.5,
#         2000. , 2005.5, 2011. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# **4. Create a Distribution Plot of the Album `Spotify Reproduction Count` for just for the Albums on the Top 100 of the list**

# %%
#### YOUR CODE HERE
# Out:
# (array([ 8., 29., 52., 46., 64., 60., 57., 45., 28., 12.]),
#  array([ 987675. ,  994209.9, 1000744.8, 1007279.7, 1013814.6, 1020349.5,
#         1026884.4, 1033419.3, 1039954.2, 1046489.1, 1053024. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# **5. Create a BoxPlot of the Spotify Reproduction Count by the following Genres: 'Hip Hop', 'Electronic', 'Blues' and 'Pop'. Make the plot bigger that the standard output (15, 8) and make the title bigger (Size=20) and Green**

# %%
#### YOUR CODE HERE
# Get the desired data first

# Plot the Boxplot

pass

# %% [markdown]
# **6. Create a Scatter Plot between the Year and Spotify Reproduction Count. Make it also on a figure size of (15,8)**

# %%
#### YOUR CODE HERE

pass

# %% [markdown]
# **7. Show Two Scatter Plot on one line: the first with the Year and Reproduction Count for Blues, and the other for Electronic. Set the Title for each Plot to be able to indentify them. Hiphop dots must be Red.**

# %%
#### YOUR CODE HERE

pass

# %% [markdown]
# **8. We are going to show how many albums per Genre are on the Top 500 List. Group the data on Genre and create a Bar Chart of the Top 25 Categories, Descending Ordered, to show the comparision among the variable**

# %%
# Create the grouped dataframe

# %%
# Create the plot

pass

# %% [markdown]
# **9. Now, we want to create a Bar Chart that will show how many albums of an artist are on the Top 500 List.**

# %%
### Create the dataframe for the Visualization

# %%
### Create the plot

pass

# %% [markdown]
# **10. Create a Heat Map that shows the relationship about the genre, year and the Spotify Reproduction Count for the following categories: 'Blues', 'Funk &/ Soul','Rock', 'Rock, Pop'. And for the following range of years: 1955-1975. Also for the Color Pallete used 'YlGnBu'**

# %%
### Create the dataframe for the Visualization

# %%
### Create the plot

pass
